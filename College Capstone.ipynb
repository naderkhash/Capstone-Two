# %%
import pandas as pd
# Opening each of the CSV files
degrees = pd.read_csv(r'C:\Users\Nader\Desktop\Coding Stuff\Springboard\Caapstone\College Idea\degrees-that-pay-back.csv')
salaries = pd.read_csv(r'C:\Users\Nader\Desktop\Coding Stuff\Springboard\Caapstone\College Idea\salaries-by-region.csv')
college = pd.read_csv(r'C:\Users\Nader\Desktop\Coding Stuff\Springboard\Caapstone\College Idea\salaries-by-college-type.csv')
tuition = pd.read_csv(r'C:\Users\Nader\Desktop\Coding Stuff\Springboard\Caapstone\College Idea\tuition_cost.csv')
# Cleaning up college data
college_clean = college.drop(columns=['Mid-Career 25th Percentile Salary', 'Mid-Career 10th Percentile Salary', 'Mid-Career 75th Percentile Salary', 'Mid-Career 90th Percentile Salary'])
college_clean.rename(columns = {'Starting Median Salary': 'Starting Median Salary (College)', 'Mid-Career Median Salary' : 'Mid-Career Median Salary (College)'})
college_clean
# Out:
#                                       School Name  School Type  \
# 0     Massachusetts Institute of Technology (MIT)  Engineering
# 1        California Institute of Technology (CIT)  Engineering
# 2                             Harvey Mudd College  Engineering
# 3    Polytechnic University of New York, Brooklyn  Engineering
# 4                                    Cooper Union  Engineering
# ..                                            ...          ...
# 264                  Austin Peay State University        State
# 265                    Pittsburg State University        State
# 266                      Southern Utah University        State
# 267           Montana State University - Billings        State
# 268                  Black Hills State University        State
#
#     Starting Median Salary Mid-Career Median Salary
# 0               $72,200.00              $126,000.00
# 1               $75,500.00              $123,000.00
# ...

# %%
# Dropping unneccessary columns from salaries
salaries_clean = salaries.drop(columns = ['Mid-Career 25th Percentile Salary', 'Mid-Career 10th Percentile Salary', 'Mid-Career 75th Percentile Salary', 'Mid-Career 90th Percentile Salary'])
salaries_clean
# Out:
#                                          School Name        Region  \
# 0                                Stanford University    California
# 1           California Institute of Technology (CIT)    California
# 2                                Harvey Mudd College    California
# 3                 University of California, Berkeley    California
# 4                                 Occidental College    California
# ..                                               ...           ...
# 315   State University of New York (SUNY) at Potsdam  Northeastern
# 316                               Niagara University  Northeastern
# 317  State University of New York (SUNY) at Fredonia  Northeastern
# 318                     University of Southern Maine  Northeastern
# 319                                    Mercy College  Northeastern
#
#     Starting Median Salary Mid-Career Median Salary
# 0               $70,400.00              $129,000.00
# 1               $75,500.00              $123,000.00
# ...

# %%
# Merging the salaries and college datasets 
salaries_college = pd.merge(salaries_clean, college_clean, how='left', on='School Name')
salaries_college
Colleges = salaries_college.drop(columns=['Starting Median Salary_y', 'Mid-Career Median Salary_y'])
Colleges = Colleges.rename(columns = {'Starting Median Salary_x': 'Starting Median Salary', 'Mid-Career Median Salary_x': 'Mid Career Median Salary'})

# %%
tuition.columns
tuition = tuition.rename(columns={'name': 'School Name'})

# %%
# Cleaning the degrees dataset
degrees_clean = degrees.drop(columns=['Mid-Career 25th Percentile Salary', 'Percent change from Starting to Mid-Career Salary','Mid-Career 10th Percentile Salary', 'Mid-Career 75th Percentile Salary', 'Mid-Career 90th Percentile Salary'])
# Out:
#                      Undergraduate Major Starting Median Salary  \
# 43                   Physician Assistant             $74,300.00
# 8                   Chemical Engineering             $63,200.00
# 12                  Computer Engineering             $61,400.00
# 19                Electrical Engineering             $60,900.00
# 38                Mechanical Engineering             $57,900.00
# 1                  Aerospace Engineering             $57,700.00
# 30                Industrial Engineering             $57,700.00
# 13                      Computer Science             $55,900.00
# 40                               Nursing             $54,200.00
# 10                     Civil Engineering             $53,900.00
# 14                          Construction             $53,700.00
# 44                               Physics             $50,300.00
# 17                             Economics             $50,100.00
# 35  Management Information Systems (MIS)             $49,200.00
# ...

# %%
tuition = tuition.drop(columns =['type', 'state', 'state_code', 'degree_length', 'in_state_total', 'room_and_board', 'out_of_state_total'])

# %%
tuition = tuition.set_index('School Name')

# %%
x = tuition.index.isin(Colleges['School Name'])
tuition = tuition[x]
tuition = tuition.rename(columns={'in_state_tuition':'In State Tuition', 'out_of_state_tuition': 'Out of State Tuition'})

# %%
# Merging colleges and tuitions
colleges_tuition = pd.merge(Colleges, tuition, how='left', on='School Name')

# %%
colleges_tuition
# Out:
#                                          School Name        Region  \
# 0                                Stanford University    California
# 1           California Institute of Technology (CIT)    California
# 2                                Harvey Mudd College    California
# 3                 University of California, Berkeley    California
# 4                                 Occidental College    California
# ..                                               ...           ...
# 337   State University of New York (SUNY) at Potsdam  Northeastern
# 338                               Niagara University  Northeastern
# 339  State University of New York (SUNY) at Fredonia  Northeastern
# 340                     University of Southern Maine  Northeastern
# 341                                    Mercy College  Northeastern
#
#     Starting Median Salary Mid Career Median Salary   School Type  \
# 0               $70,400.00              $129,000.00           NaN
# ...

# %%
colleges_tuition.sort_values('Starting Median Salary', ascending=False)
# Out:
#                                      School Name        Region  \
# 1       California Institute of Technology (CIT)    California
# 239  Massachusetts Institute of Technology (MIT)  Northeastern
# 2                            Harvey Mudd College    California
# 0                            Stanford University    California
# 238                         Princeton University  Northeastern
# ..                                           ...           ...
# 229                          Mississippi College      Southern
# 146                 Black Hills State University    Midwestern
# 228                    Morehead State University      Southern
# 234              Virginia Wesleyan College (VWC)      Southern
# 235               Lee University (Cleveland, TN)      Southern
#
#     Starting Median Salary Mid Career Median Salary  School Type  \
# 1               $75,500.00              $123,000.00  Engineering
# 239             $72,200.00              $126,000.00  Engineering
# ...

# %%
degrees_clean
# Out:
#                      Undergraduate Major Starting Median Salary  \
# 0                             Accounting             $46,000.00
# 1                  Aerospace Engineering             $57,700.00
# 2                            Agriculture             $42,600.00
# 3                           Anthropology             $36,800.00
# 4                           Architecture             $41,600.00
# 5                            Art History             $35,800.00
# 6                                Biology             $38,800.00
# 7                    Business Management             $43,000.00
# 8                   Chemical Engineering             $63,200.00
# 9                              Chemistry             $42,600.00
# 10                     Civil Engineering             $53,900.00
# 11                        Communications             $38,100.00
# 12                  Computer Engineering             $61,400.00
# 13                      Computer Science             $55,900.00
# ...
